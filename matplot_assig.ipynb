# %% [raw]
# Question-No.1

# %% [raw]
# Matplotlib is a popular 2D plotting library for Python. It provides a flexible and comprehensive way to create a wide range of static, animated, and interactive visualizations in Python. Matplotlib is widely used in data visualization, scientific plotting, and creating various types of graphs and charts.
# We use matplotlib for the following regions--
#
# 1- Data Visualization
# 2- Presentation
# 3- Exploration
# 4- Communication
#
# Some common plots that can be created using the Pyplot module of Matplotlib include:
# 1-Line Plot: A basic plot that shows the relationship between two variables using lines connecting data points.
#
# 2-Bar Plot: Used to compare different categories or groups using vertical or horizontal bars.
#
# 3-Histogram: Displays the distribution of a continuous variable by dividing it into bins and showing the frequency   of data points in each bin.
#
# 4-Scatter Plot: Represents individual data points as dots on a 2D plane, useful for visualizing the correlation       between two variables.
#
# 5-Pie Chart: Displays the proportion of different categories in a dataset as segments of a circle, useful for         illustrating parts of a whole.

# %% [raw]
# Question-No.2

# %% [raw]
# Scatter plot - A scatter plot is a type of data visualization that displays individual data points as dots on a                   two-dimensional plane. Each dot represents the values of two variables, one plotted along the x-axis  and the other plotted along the y-axis. Scatter plots are used to visualize the relationship or correlation between two variables.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.figure(figsize=(8, 6))

plt.scatter(x , y , alpha=0.7)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Scatter Plot')
plt.grid(True)
plt.show()

# %% [raw]
# Question-No.3

# %% [raw]
# The 'subplot()' function in Matplotlib is used to create a grid of subplots within a single figure. It allows you to display multiple plots in a single figure, making it easier to compare different visualizations or data representations.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])


plt.figure(figsize=(10, 8))

# Subplot 1
plt.subplot(2, 2, 1)  
plt.plot(x, y1, label='Line 1')
plt.title('Line Plot 1')
plt.legend()

# Subplot 2
plt.subplot(2, 2, 2)  
plt.plot(x, y2, label='Line 2', color='orange')
plt.title('Line Plot 2')
plt.legend()

# Subplot 3
plt.subplot(2, 2, 3)  
plt.plot(x, y3, label='Line 3', color='green')
plt.title('Line Plot 3')
plt.legend()

# Subplot 4
plt.subplot(2, 2, 4) 
plt.plot(x, y4, label='Line 4', color='red')
plt.title('Line Plot 4')
plt.legend()


plt.tight_layout()


plt.show()
